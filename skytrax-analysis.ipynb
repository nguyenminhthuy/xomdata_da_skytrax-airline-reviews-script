# %% [markdown]
# pip install sqlalchemy pyodbc

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
from sqlalchemy import create_engine
import pandas as pd

host = "45.124.94.158"
port = 1433
database = "xomdata_dataset"
username = "ntmthuy1264140"
password = "9MRA8!f0U7vVr$"

connection_string = (
    f"mssql+pyodbc://{username}:{password}@{host}:{port}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)

engine = create_engine(connection_string)

query = """
SELECT *
FROM skytrax.airline_reviews
"""

df = pd.read_sql(query, engine)

print(df.head())
# Out:
#    review_id  airline_id  verify date_submitted date_flown    customer_name  \
# 0          1         313   False     2002-01-06       None  Joshua Torres 6
# 1          2         313   False     2002-01-06       None  Joshua Torres 6
# 2          3         466   False     2002-02-14       None   Cynthia Lee 30
# 3          4         313   False     2002-03-21       None      Donna Lee 9
# 4          5         313   False     2002-03-21       None      Donna Lee 9
#
#                                          nationality type_of_traveller  \
# 0                                            flt. 93               NaN
# 1                                            flt. 93               NaN
# 2                                                NaN               NaN
# 3  thin around 40 about 5'5' dark hair to his sho...               NaN
# 4  thin around 40 about 5'5' dark hair to his sho...               NaN
#
#   seat_type aircraft  ... seat_comfort cabin_staff_service food_and_beverages  \
# 0       NaN      NaN  ...          NaN                 NaN                NaN
# 1       NaN      NaN  ...          NaN                 NaN                NaN
# 2       NaN      NaN  ...          NaN                 NaN                NaN
# 3       NaN      NaN  ...          NaN                 NaN                NaN
# 4       NaN      NaN  ...          NaN                 NaN                NaN
#
#   inflight_entertainment ground_service wifi_and_connectivity  \
# 0                    NaN            NaN                   NaN
# 1                    NaN            NaN                   NaN
# 2                    NaN            NaN                   NaN
# 3                    NaN            NaN                   NaN
# 4                    NaN            NaN                   NaN
#
#    value_for_money  recommended  \
# 0              NaN        False
# 1              NaN        False
# 2              NaN        False
# 3              NaN        False
# 4              NaN        False
#
#                                               review          updated_at
# 0  I flew Lan Peru on a domestic flight from Lima... 2026-04-03 14:30:19
# 1  I flew Lan Peru on a domestic flight from Lima... 2026-04-03 14:30:19
# 2  Skymark is a low-fare airline in Japan. I flow... 2026-04-03 14:30:19
# 3  I have flown LanPeru into and out of Cuzco man... 2026-04-03 14:30:19
# 4  I have flown LanPeru into and out of Cuzco man... 2026-04-03 14:30:19
#
# [5 rows x 26 columns]
